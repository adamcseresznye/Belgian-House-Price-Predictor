# %% [raw]
# ---
# title: '...'
# author: Adam Cseresznye
# date: '2023-09-19'
# categories:
#   - project
# jupyter: python3
# toc: true
# format:
#   html:
#     code-fold: true
#     code-tools: true
# ---

# %% [markdown]
# ![Photo by Stephen Phillips - Hostreviews.co.uk on UnSplash](https://cf.bstatic.com/xdata/images/hotel/max1024x768/408003083.jpg?k=c49b5c4a2346b3ab002b9d1b22dbfb596cee523b53abef2550d0c92d0faf2d8b&o=&hp=1){fig-align="center" width=50%}

# %% [markdown]
# # Import data

# %%
import time
from pathlib import Path

import pandas as pd
from data import utils
from lets_plot import *
from lets_plot.mapping import as_discrete

LetsPlot.setup_html()
# Out:
#             <div id="c0GBoW"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.2.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("c0GBoW").appendChild(div);
#                     };
#                     var e = document.getElementById("c0GBoW");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# ::: {.callout-tip title="How to import your own module using a .pth file"}
# Based on [this SO question](https://stackoverflow.com/questions/700375/how-to-add-a-python-import-path-using-a-pth-file), I added the sth.pth file containing `C:\Users\s0212777\OneDrive - Universiteit Antwerpen\Jupyter_projects\Articles\house_price_prediction\src` into the folder: C:\Users\s0212777\AppData\Roaming\Python\Python310\site-packages. This folder is already in my `PYTHONPATH` so that Python can see my package directory (check with `import sys sys.path`).
#
# So now utils can be imported as `from data import utils`.
#
# :::

# %% [markdown]
# # Determine what columns to keep depending on the number of missing values present

# %%
# I prescraped some ads so that I can see what columns are more likely to be missing

path = utils.Configuration.RAW_DATA_PATH.joinpath("for_sale").glob("*.csv")

csvs = []
for i in path:
    csvs.append(pd.read_csv(i).T)
len(csvs)
# Out:
# 33

# %%
# we also transpose the dataframes so that the columns become the indexes (helps with concat)
dfs = pd.concat([i for i in csvs], axis=1).T

# %%
dfs.shape
# Out:
# (1024, 434)

# %%
dfs.dropna(axis=0, how="all")
# Out:
#    Accessible for disabled people  \
# 0                             Yes
# 1                             Yes
# 2                              No
# 3                             NaN
# 4                             Yes
# ..                            ...
# 25                            NaN
# 26                             No
# 27                            NaN
# 28                            NaN
# 29                            NaN
#
#                                               Address         Available as of  \
# 0               Grotestraat 28 9500  - Geraardsbergen  After signing the deed
# 1           Gistelsesteenweg 291 8200  - Sint Andries             Immediately
# 2    Dokter Honore Dewolfstraat 23 9700  - Oudenaarde                     NaN
# 3                          Parklaan 187 9300  - Aalst             Immediately
# 4               Grotestraat 28 9500  - Geraardsbergen           To be defined
# ..                                                ...                     ...
# 25                   Ieperstraat 35 8970  - Poperinge             Immediately
# 26                    Brugsestraat 1 8020  - Oostkamp                     NaN
# 27  Alphonse Claeys-Bouüaertlaan 57/001 9030  - Ma...                     NaN
# 28              Place Paul Heupgen 9/4.1 7000  - Mons                     NaN
# 29                   Av. de Jemappes 173 7000  - Mons                     NaN
#
#    Bathrooms Bedrooms Building condition    CO₂ emission  \
# 0          2        4               Good   Not specified
# 1          1        5        To renovate   Not specified
# 2          2        3             As new  9714 kg CO₂/m²
# 3          2        3     Just renovated   Not specified
# 4          1        2      To be done up   Not specified
# ..       ...      ...                ...             ...
# 25       1.0        4        To renovate   Not specified
# 26       1.0        3      To be done up   Not specified
# 27       1.0        5      To be done up   Not specified
# 28       2.0        5               Good   Not specified
# 29       NaN        4               Good    84 kg CO₂/m²
#
#    Connection to sewer network Construction year Covered parking spaces  ...  \
# 0                    Connected            1967.0                    1.0  ...
# 1                    Connected            1954.0                    1.0  ...
# 2                    Connected            1982.0                    1.0  ...
# 3                          NaN               NaN                    NaN  ...
# 4                          NaN               NaN                    1.0  ...
# ..                         ...               ...                    ...  ...
# 25                         NaN               NaN                    NaN  ...
# 26                   Connected            1974.0                    NaN  ...
# 27                   Connected            1899.0                    NaN  ...
# 28                   Connected               NaN                    NaN  ...
# 29                         NaN               NaN                    NaN  ...
#
#    TB1.A.c.4.1 TB1.A.c.4.2 TB1.A.c.4.3 TB1.A.c.5.1 TB1.A.c.5.2 TB1.A.c.5.3  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 25         NaN         NaN         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN         NaN
#
#    TB1.A.c.6.1 TB1.A.c.6.2 How many fireplaces? Current monthly revenue
# 0          NaN         NaN                  NaN                     NaN
# 1          NaN         NaN                  NaN                     NaN
# 2          NaN         NaN                  NaN                     NaN
# 3          NaN         NaN                  NaN                     NaN
# 4          NaN         NaN                  NaN                     NaN
# ..         ...         ...                  ...                     ...
# 25         NaN         NaN                  NaN                     NaN
# 26         NaN         NaN                  NaN                     NaN
# 27         NaN         NaN                  NaN                     NaN
# 28         NaN         NaN                  NaN                     NaN
# 29         NaN         NaN                  NaN                     NaN
#
# [1009 rows x 434 columns]

# %%
# Getting the column names with lowest missing values
lowest_missing_value_columns = (
    dfs.notna()
    .sum()
    .div(dfs.shape[0])
    .mul(100)
    .sort_values(ascending=False)
    .head(50)
    .round(1)
)
print(lowest_missing_value_columns)
indexes_to_keep = lowest_missing_value_columns.index
# Out:
# day_of_retrieval                                  98.0
# ad_url                                            98.0
# Reference number of the EPC report                94.8
# Energy class                                      94.8
# Primary energy consumption                        94.8
# Yearly theoretical total energy consumption       94.8
# CO₂ emission                                      94.8
# Tenement building                                 93.7
# Address                                           89.1
# Bedrooms                                          86.8
# Living area                                       80.7
# Bathrooms                                         78.9
# Surface of the plot                               76.9
# Price                                             75.3
# Building condition                                71.4
# Double glazing                                    70.3
# Number of frontages                               64.5
# Website                                           59.8
# Toilets                                           57.3
# External reference                                52.0
# Heating type                                      42.4
# Cadastral income                                  40.7
# Gas, water & electricity                          34.0
# Latest land use designation                       32.5
# Connection to sewer network                       31.3
# Covered parking spaces                            29.4
# Possible priority purchase right                  28.2
# Proceedings for breach of planning regulations    27.3
# Construction year                                 27.0
# Subdivision permit                                26.1
# Bedroom 1 surface                                 26.0
# Bedroom 2 surface                                 25.7
# Available as of                                   24.9
# Kitchen type                                      23.6
# Flood zone type                                   23.6
# Living room surface                               23.0
# Planning permission obtained                      21.8
# Kitchen surface                                   21.5
# TV cable                                          18.7
# Bedroom 3 surface                                 18.2
# Furnished                                         17.7
# Outdoor parking spaces                            16.3
# Surroundings type                                 16.0
# Garden surface                                    13.9
# Basement                                          13.8
# Width of the lot on the street                    11.8
# Street frontage width                             11.7
# Office                                            11.1
# As built plan                                     10.4
# Dining room                                       10.4
# dtype: float64
